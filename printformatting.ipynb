# %%
#this is how we add sentences or words or anything to a string using some print formats
#first we are looking at .format

# %%
print("hello my name is rishabh {}".format("and i am the best"))
# Out:
# hello my name is rishabh and i am the best

# %%
print('hey {2} {1} {0} '.format('name', 'is', 'rishabh'))
# Out:
# hey rishabh is name
