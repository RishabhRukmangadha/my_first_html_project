# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = a+a

# %%
a
# Out:
# 80

# %%
type(a)
# Out:
# int

# %%
a = "rishi"

# %%
type(a)
# Out:
# str

# %%
my_income = 100
tax_rate = 0.1
my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 10.0
