# %%
1+1
# Out:
# 2

# %%
1-1
# Out:
# 0

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %%
7/4
# Out:
# 1.75

# %%
7//4
# Out:
# 1

# %%
7%4
# Out:
# 3

# %%
7**2
# Out:
# 49

# %%
1/1.1
# Out:
# 0.9090909090909091
